# %%
import scrapy

# %%
class Spider12(scrapy.Spider):
    name = 'spider12'
    allowed_domains = ['pagina12.com.ar']
    custom_settings = {'FEED_FORMAT': 'json', 
                       'FEED_URI': 'resultados.json', 
                       'FEED_EXPORT_ENCODING': 'utf-8',
                       'DEPTH_LIMIT': 2}
    
    start_urls = ['https://www.pagina12.com.ar/secciones/el-pais',
                  'https://www.pagina12.com.ar/secciones/economia',
                  'https://www.pagina12.com.ar/secciones/sociedad',
                  'https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos',
                  'https://www.pagina12.com.ar/secciones/el-mundo',
                  'https://www.pagina12.com.ar/secciones/deportes',
                  'https://www.pagina12.com.ar/secciones/contratapa',
                  'https://www.pagina12.com.ar/secciones/audiovisuales']
    
    def parse(self, response):
        # Articulo Promocionado 
        nota_promocionada = response.xpath['//div[class="featured-article_container"]/h2/a/@href'].get()
        if nota_promocionada is not None:
            yield response.follow(nota_promocionada, callback = self.parse_nota)
            
        # listado de notas
        notas = response.xpath('//ul[@class= "article-list"]//li//a/@href').getall()
        for nota in notas:
            yield response.follow(nota, callback = self.parse_nota)
            
        #Link a la siguiente página
        next_page = response.xpath('//a[@class="pagination-btn-next"]/@href')
        if next_page is not None:
            yield response.follow(next_page, callback = self.parse)
            
    def parse_nota(self, response):
        #Parseo de la nota
        titulo = response.xpath('//div[@class="article-tittle"]/text()').get()
        cuerpo = ''.join(response.xpath('//div[@class="article-text"]/p/text()').getall())
        yield {'url': response.url, 
              'titulo': titulo, 
              'cuerpo': cuerpo}

# %%
from scrapy.crawler import CrawlerProcess

# %%
process = CrawlerProcess()
process.crawl(Spider12)
process.start()
# Out:
# 2021-08-06 12:13:49 [scrapy.utils.log] INFO: Scrapy 2.5.0 started (bot: scrapybot)
# 2021-08-06 12:13:49 [scrapy.utils.log] INFO: Versions: lxml 4.6.3.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 20.0.1 (OpenSSL 1.1.1k  25 Mar 2021), cryptography 3.4.7, Platform Windows-10-10.0.19041-SP0
# 2021-08-06 12:13:49 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-08-06 12:13:49 [scrapy.crawler] INFO: Overridden settings:
# {'DEPTH_LIMIT': 2}
# 2021-08-06 12:13:49 [scrapy.extensions.telnet] INFO: Telnet Password: 5d04a2027fea23b5
# 2021-08-06 12:13:49 [py.warnings] WARNING: C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\extensions\feedexport.py:247: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)
#
# 2021-08-06 12:13:49 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2021-08-06 12:13:49 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2021-08-06 12:13:49 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2021-08-06 12:13:49 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2021-08-06 12:13:49 [scrapy.core.engine] INFO: Spider opened
# 2021-08-06 12:13:49 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2021-08-06 12:13:49 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2021-08-06 12:13:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.pagina12.com.ar/secciones/el-pais> (referer: None)
# 2021-08-06 12:13:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.pagina12.com.ar/secciones/deportes> (referer: None)
# 2021-08-06 12:13:50 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.pagina12.com.ar/secciones/deportes> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 120, in iter_errback
#     yield next(it)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "<ipython-input-5-6e3347f8e0a3>", line 19, in parse
#     nota_promocionada = response.xpath['//div[class="featured-article_container"]/h2/a/@href'].get()
# TypeError: 'method' object is not subscriptable
# 2021-08-06 12:13:50 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.pagina12.com.ar/secciones/el-pais> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 120, in iter_errback
#     yield next(it)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "<ipython-input-5-6e3347f8e0a3>", line 19, in parse
#     nota_promocionada = response.xpath['//div[class="featured-article_container"]/h2/a/@href'].get()
# TypeError: 'method' object is not subscriptable
# 2021-08-06 12:13:50 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos/06-08-2021> from <GET https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos>
# 2021-08-06 12:13:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.pagina12.com.ar/secciones/el-mundo> (referer: None)
# 2021-08-06 12:13:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.pagina12.com.ar/secciones/economia> (referer: None)
# 2021-08-06 12:13:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.pagina12.com.ar/secciones/audiovisuales> (referer: None)
# 2021-08-06 12:13:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.pagina12.com.ar/secciones/contratapa> (referer: None)
# 2021-08-06 12:13:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.pagina12.com.ar/secciones/sociedad> (referer: None)
# 2021-08-06 12:13:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos/06-08-2021> (referer: None)
# 2021-08-06 12:13:50 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.pagina12.com.ar/secciones/el-mundo> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 120, in iter_errback
#     yield next(it)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "<ipython-input-5-6e3347f8e0a3>", line 19, in parse
#     nota_promocionada = response.xpath['//div[class="featured-article_container"]/h2/a/@href'].get()
# TypeError: 'method' object is not subscriptable
# 2021-08-06 12:13:50 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.pagina12.com.ar/secciones/economia> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 120, in iter_errback
#     yield next(it)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "<ipython-input-5-6e3347f8e0a3>", line 19, in parse
#     nota_promocionada = response.xpath['//div[class="featured-article_container"]/h2/a/@href'].get()
# TypeError: 'method' object is not subscriptable
# 2021-08-06 12:13:50 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.pagina12.com.ar/secciones/audiovisuales> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 120, in iter_errback
#     yield next(it)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "<ipython-input-5-6e3347f8e0a3>", line 19, in parse
#     nota_promocionada = response.xpath['//div[class="featured-article_container"]/h2/a/@href'].get()
# TypeError: 'method' object is not subscriptable
# 2021-08-06 12:13:50 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos/06-08-2021> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 120, in iter_errback
#     yield next(it)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "<ipython-input-5-6e3347f8e0a3>", line 19, in parse
#     nota_promocionada = response.xpath['//div[class="featured-article_container"]/h2/a/@href'].get()
# TypeError: 'method' object is not subscriptable
# 2021-08-06 12:13:50 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.pagina12.com.ar/secciones/contratapa> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 120, in iter_errback
#     yield next(it)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "<ipython-input-5-6e3347f8e0a3>", line 19, in parse
#     nota_promocionada = response.xpath['//div[class="featured-article_container"]/h2/a/@href'].get()
# TypeError: 'method' object is not subscriptable
# 2021-08-06 12:13:50 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.pagina12.com.ar/secciones/sociedad> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 120, in iter_errback
#     yield next(it)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\utils\python.py", line 353, in __next__
#     return next(self.data)
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\jm_yg\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 56, in _evaluate_iterable
#     for r in iterable:
#   File "<ipython-input-5-6e3347f8e0a3>", line 19, in parse
#     nota_promocionada = response.xpath['//div[class="featured-article_container"]/h2/a/@href'].get()
# TypeError: 'method' object is not subscriptable
# 2021-08-06 12:13:50 [scrapy.core.engine] INFO: Closing spider (finished)
# 2021-08-06 12:13:50 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2218,
#  'downloader/request_count': 9,
#  'downloader/request_method_count/GET': 9,
#  'downloader/response_bytes': 161545,
#  'downloader/response_count': 9,
#  'downloader/response_status_count/200': 8,
#  'downloader/response_status_count/302': 1,
#  'elapsed_time_seconds': 0.679387,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2021, 8, 6, 17, 13, 50, 289580),
#  'httpcompression/response_bytes': 795793,
#  'httpcompression/response_count': 8,
#  'log_count/DEBUG': 9,
#  'log_count/ERROR': 8,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'response_received_count': 8,
#  'scheduler/dequeued': 9,
#  'scheduler/dequeued/memory': 9,
#  'scheduler/enqueued': 9,
#  'scheduler/enqueued/memory': 9,
#  'spider_exceptions/TypeError': 8,
#  'start_time': datetime.datetime(2021, 8, 6, 17, 13, 49, 610193)}
# 2021-08-06 12:13:50 [scrapy.core.engine] INFO: Spider closed (finished)
